# %%
pip install numpy

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1.- Definimos la función
def f(x):
    return 3*x + 4*np.exp(-4*x)

# %%
# 2.- Generamos un rango de valores de x
x = np.linspace(-2, 2, 400)

# %%
# 3.- Calculamos los valores de y
y = f(x)

# %%
# 4.- Graficar la función
plt.figure(figsize=(8, 6))
plt.plot(x, y, label='f(x) = 3x + 4e^(-4x)')
plt.title('Gráfico de la función')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 5.- Definimos la función
def f(x):
    return 5*x*(3*x + 1) - 8*x**2 - 3*x

# %%
# 6.- Generamos un rango de valores de x
x = np.linspace(-10, 10, 400)

# %%
# 7.- Definimos los valores de y
y = f(x)

# %%
# 8.- Graficamos la función
plt.figure(figsize=(8, 6))
plt.plot(x, y, label='f(x) = 5x(3x+1) - 8x^2 - 3x')
plt.title('Gráfico de la función')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Importa la biblioteca SymPy
import sympy as sp

# Define las variables simbólicas
x = sp.symbols('x')

# Define las funciones
f1 = 4*x**4 + 6*x**2 + sp.exp(4*x**2)
f2 = 1 / (2*x**3) + 8*x

# Calcula la segunda derivada de la primera función (f1)
f1_second_derivative = sp.diff(f1, x, 2)

# Calcula la segunda derivada de la segunda función (f2)
f2_second_derivative = sp.diff(f2, x, 2)

# Imprime las segundas derivadas
print("Segunda derivada de f1:")
print(f1_second_derivative)

print("\nSegunda derivada de f2:")
print(f2_second_derivative)
# Out:
# Segunda derivada de f1:
# 4*(16*x**2*exp(4*x**2) + 12*x**2 + 2*exp(4*x**2) + 3)
#
# Segunda derivada de f2:
# 6/x**5
